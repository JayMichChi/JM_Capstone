# %% [markdown]
# ## Dataframe construction

# %%
import pandas as pd

# %%
import pandas as pd
df1 = pd.read_csv('../Part 2 Capstone/df2.csv')
# Out:
# /Users/ugp/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for column in df1.columns:
    print df1[column].describe()
# Out:
# count    994039.000000
# mean      28342.562048
# std       17292.874500
# min           0.000000
# 25%       13806.000000
# 50%       27612.000000
# 75%       41418.000000
# max       79091.000000
# Name: Unnamed: 0, dtype: float64
# count    994039.000000
# mean     200515.128781
# std         514.703215
# min      199601.000000
# 25%      200103.000000
# 50%      200512.000000
# 75%      201003.000000
# max      201310.000000
# Name: BEGIN_YEARMONTH, dtype: float64
# count    994039.000000
# mean         14.891068
# std           9.178259
# min           1.000000
# 25%           7.000000
# 50%          15.000000
# 75%          23.000000
# max          31.000000
# Name: BEGIN_DAY, dtype: float64
# count    994039.000000
# mean       1290.468152
# std         682.994668
# min           0.000000
# 25%         800.000000
# 50%        1500.000000
# 75%        1812.000000
# max        2359.000000
# Name: BEGIN_TIME, dtype: float64
# count    994039.000000
# mean     200515.131411
# ...

# %%
df1.shape
# Out:
# (994039, 31)

# %%
df1.EVENT_TYPE.unique()
# Out:
# array(['Winter Storm', 'Flood', 'High Wind', 'Tornado', 'Lightning',
#        'Waterspout', 'OTHER', 'Heavy Rain', 'Drought', 'Rip Current',
#        'Wildfire', 'Tropical Storm', 'Hurricane', 'Tsunami', 'Landslide'], dtype=object)

# %% [markdown]
# ## Below i will construct a number of dataframes that I will subsequently run both regression and classification models on.

# %%
df1.columns
# Out:
# Index([u'Unnamed: 0', u'BEGIN_DAY', u'EPISODE_ID', u'EVENT_ID', u'STATE',
#        u'YEAR', u'MONTH_NAME', u'EVENT_TYPE', u'CZ_NAME', u'WFO',
#        u'INJURIES_DIRECT', u'INJURIES_INDIRECT', u'DEATHS_DIRECT',
#        u'DEATHS_INDIRECT', u'DAMAGE_PROPERTY', u'DAMAGE_CROPS', u'FLOOD_CAUSE',
#        u'CATEGORY', u'TOR_F_SCALE', u'TOR_LENGTH', u'TOR_WIDTH',
#        u'TOR_OTHER_WFO', u'TOR_OTHER_CZ_STATE', u'END_LAT',
#        u'EPISODE_NARRATIVE', u'EVENT_NARRATIVE', u'CASUALTIES',
#        u'TOTAL_DEATHS', u'TOTAL_INJURIES', u'DATE', u'COMBINED_DAMAGE'],
#       dtype='object')

# %%
a = pd.DataFrame(df1.groupby('EVENT_TYPE').CASUALTIES.agg(['count','min', 'max', 'mean', 'sum', ]).sort_values('sum', axis=0, ascending=False).reset_index().head(11))

# %%
a.head(15)
# Out:
#       EVENT_TYPE   count  min   max      mean    sum
# 0        Tornado   31568    0  1311  0.723803  22849
# 1        Drought   65644    0   521  0.257221  16885
# 2   Winter Storm  414873    0   300  0.027572  11439
# 3          Flood   99038    0   802  0.102587  10160
# 4      High Wind  319759    0   101  0.027055   8651
# 5      Lightning   14229    0    51  0.377961   5378
# 6      Hurricane    1777    0  2409  2.181204   3876
# 7          OTHER    9897    0    64  0.224108   2218
# 8       Wildfire    5251    0   104  0.403923   2121
# 9    Rip Current    8325    0    55  0.209730   1746
# 10    Heavy Rain   15217    0    52  0.037064    564

# %%
a1 = dfs.groupby('EVENT_TYPE').CASUALTIES.agg(['max']).sort_values('max', axis=0, ascending=False).reset_index().head(10)
a1
# Out:
#        EVENT_TYPE   max
# 0       Hurricane  2409
# 1         Tornado  1311
# 2           Flood   802
# 3         Drought   521
# 4    Winter Storm   300
# 5         Tsunami   180
# 6  Tropical Storm   154
# 7        Wildfire   104
# 8       High Wind   101
# 9           OTHER    64

# %%
dfs[(dfs.CASUALTIES == 2409) & (dfs.EVENT_TYPE == 'Hurricane') | 
    (dfs.CASUALTIES == 1311) & (dfs.EVENT_TYPE == 'Tornado') | 
    (dfs.CASUALTIES == 802) & (dfs.EVENT_TYPE == 'Flood') |
    (dfs.CASUALTIES == 521) & (dfs.EVENT_TYPE == 'Drought') | 
    (dfs.CASUALTIES == 300) & (dfs.EVENT_TYPE == 'Winter Storm') | 
    (dfs.CASUALTIES == 180) & (dfs.EVENT_TYPE == 'Tsunami') | 
    (dfs.CASUALTIES == 177) & (dfs.EVENT_TYPE == 'Wildfire') | 
    (dfs.CASUALTIES == 172) & (dfs.EVENT_TYPE == 'High Wind')     
    
    
   ].sort_values('CASUALTIES', axis=0, ascending=False)
# Out:
#          index  Unnamed: 0  BEGIN_DAY  EPISODE_ID  EVENT_ID           STATE  \
# 667464  667464       60644         12       23202    136433           TEXAS
# 832105  832105       33549         22       49972    296617        MISSOURI
# 135065  135065       44513         17     1150299   5672496           TEXAS
# 588131  588131       40469          4       10217     56732        MISSOURI
# 944941  944941        2834         24       71079    431502            UTAH
# 726432  726432       48068         29       35252    204396  AMERICAN SAMOA
#
#         YEAR MONTH_NAME    EVENT_TYPE                       CZ_NAME  \
# 667464  2008  September     Hurricane                        HARRIS
# 832105  2011        May       Tornado                        JASPER
# 135065  1998  October           Flood                         COMAL
# 588131  2007     August       Drought                     ST. LOUIS
# 944941  2013    January  Winter Storm  SALT LAKE AND TOOELE VALLEYS
# ...

# %%
a_biggest = pd.DataFrame(df1.groupby('EVENT_TYPE').casualties.agg(['max']).sort_values('max', axis=0, ascending=False).reset_index().head(11))

# %%
a_biggest.head(11)
# Out:
#              EVENT_TYPE   max
# 0   Hurricane (Typhoon)  2409
# 1               Tornado  1311
# 2           Flash Flood   802
# 3        Excessive Heat   521
# 4                 Flood   500
# 5                  Heat   450
# 6             Ice Storm   300
# 7               Tsunami   180
# 8        Winter Weather   177
# 9          Winter Storm   172
# 10       Tropical Storm   154
